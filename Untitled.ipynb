# %%
tmp_video='/mnt/lustre/xiaokun1/dataset/raw_video/20220923_有人摔倒采集-批次0930_1ren_liyukun/侧摔/卫生间-1/周五1点批次/young/141304_new.mp4'
scene_name = tmp_video.split('/')
scene_name
# Out:
# ['',
#  'mnt',
#  'lustre',
#  'xiaokun1',
#  'dataset',
#  'raw_video',
#  '20220923_有人摔倒采集-批次0930_1ren_liyukun',
#  '侧摔',
#  '卫生间-1',
#  '周五1点批次',
#  'young',
#  '141304_new.mp4']
